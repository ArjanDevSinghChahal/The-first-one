# %%
import pandas
import numpy as np
import matplotlib.pyplot as plt
DATA=pandas.read_csv("data 1.csv")

# %%
DATA.groupby('Condition of the House')['ID'].count()
# Out:
# Condition of the House
# Bad             30
# Excellent     1701
# Fair         14031
# Good          5679
# Okay           172
# Name: ID, dtype: int64

# %%
# For first 10 rows
DATA.head(10)
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520           14-Oct-17    221900.0               3
# 1  6414100192           14-Dec-17    538000.0               3
# 2  5631500400           15-Feb-16    180000.0               2
# 3  2487200875           14-Dec-17    604000.0               4
# 4  1954400510           15-Feb-16    510000.0               3
# 5  7237550310           14-May-17   1230000.0               4
# 6  1321400060           14-Jun-17    257500.0               3
# 7  2008000270           15-Jan-16    291850.0               3
# 8  2414600126           15-Apr-16    229500.0               3
# 9  3793500160           15-Mar-16    323000.0               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
# ...

# %%
# For last 10 rows
DATA.tail(10)
# Out:
#                ID Date House was Sold  Sale Price  No of Bedrooms  \
# 21603  7852140040           14-Aug-17    507250.0               3
# 21604  9834201367           15-Jan-16    429000.0               3
# 21605  3448900210           14-Oct-17    610685.0               4
# 21606  7936000429           15-Mar-16   1010000.0               4
# 21607  2997800021           15-Feb-16    475000.0               3
# 21608   263000018           14-May-17    360000.0               3
# 21609  6600060120           15-Feb-16    400000.0               4
# 21610  1523300141           14-Jun-17    402101.0               2
# 21611   291310100           15-Jan-16    400000.0               3
# 21612  1523300157           14-Oct-17    325000.0               2
#
#        No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 21603             2.50               2270.0              5536.0           2.0
# 21604             2.00               1490.0              1126.0           3.0
# ...

# %%
# For all statistical values
DATA.describe()
# Out:
#                  ID    Sale Price  No of Bedrooms  No of Bathrooms  \
# count  2.161300e+04  2.160900e+04    21613.000000     21609.000000
# mean   4.580302e+09  5.401984e+05        3.370842         2.114732
# std    2.876566e+09  3.673890e+05        0.930062         0.770138
# min    1.000102e+06  7.500000e+04        0.000000         0.000000
# 25%    2.123049e+09  3.219500e+05        3.000000         1.750000
# 50%    3.904930e+09  4.500000e+05        3.000000         2.250000
# 75%    7.308900e+09  6.450000e+05        4.000000         2.500000
# max    9.900000e+09  7.700000e+06       33.000000         8.000000
#
#        Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  Overall Grade  \
# count         21604.000000        2.160400e+04  21613.000000   21613.000000
# mean           2079.931772        1.510776e+04      1.494309       7.623467
# std             918.487597        4.142827e+04      0.539989       1.105439
# ...

# %%
# For all statistical values including strings
DATA.describe(include='all')
# Out:
#                   ID Date House was Sold    Sale Price  No of Bedrooms  \
# count   2.161300e+04               21613  2.160900e+04    21613.000000
# unique           NaN                  13           NaN             NaN
# top              NaN           15-Apr-16           NaN             NaN
# freq             NaN                2231           NaN             NaN
# mean    4.580302e+09                 NaN  5.401984e+05        3.370842
# std     2.876566e+09                 NaN  3.673890e+05        0.930062
# min     1.000102e+06                 NaN  7.500000e+04        0.000000
# 25%     2.123049e+09                 NaN  3.219500e+05        3.000000
# 50%     3.904930e+09                 NaN  4.500000e+05        3.000000
# 75%     7.308900e+09                 NaN  6.450000e+05        4.000000
# max     9.900000e+09                 NaN  7.700000e+06       33.000000
#
#         No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  \
# ...

# %%
# For all the information of the Dataset
DATA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21613 non-null  int64
#  1   Date House was Sold                        21613 non-null  object
#  2   Sale Price                                 21609 non-null  float64
#  3   No of Bedrooms                             21613 non-null  int64
#  4   No of Bathrooms                            21609 non-null  float64
#  5   Flat Area (in Sqft)                        21604 non-null  float64
#  6   Lot Area (in Sqft)                         21604 non-null  float64
#  7   No of Floors                               21613 non-null  float64
#  8   Waterfront View                            21613 non-null  object
#  9   No of Times Visited                        21613 non-null  object
# ...

# %%
# Statistical operations for a single column
DATA['Sale Price'].mean()
# Out:
# 540198.4357443658

# %%
# Quantile values for first, second and third quantile respectively
print(DATA['Sale Price'].quantile(.25))
print(DATA['Sale Price'].quantile(.50))
print(DATA['Sale Price'].quantile(.75))
# Out:
# 321950.0
# 450000.0
# 645000.0

# %%
# For unique values
DATA['Condition of the House'].unique()
# Out:
# array(['Fair', 'Excellent', 'Good', 'Bad', 'Okay'], dtype=object)

# %%
# Statistical operations using numpy
np.mean(DATA['Sale Price'])
# Out:
# 540198.4357443658

# %%
plt.plot(DATA['Sale Price'],color='green',marker='o',markerfacecolor='blue',markersize='5',linewidth=2,linestyle='dashed')
plt.xlabel=('Record Number')
plt.ylabel=('Sale Price')
plt.title=('My First Graph')
plt.show()

# %%
Labels=('Bad','Excellent','Fair','Good','Okay')
values=(30,1701,14031,5679,172)
plt.pie(values,labels=Labels)
# Out:
# ([<matplotlib.patches.Wedge at 0x20412a42440>,
# ...
#  [Text(1.099989541385049, 0.004796753434368107, 'Bad'),
#   Text(1.0641591373844368, 0.27850553014475643, 'Excellent'),
#   Text(-0.9085709380486652, 0.620079713047741, 'Fair'),
#   Text(0.7046888223897579, -0.8446381850229934, 'Good'),
#   Text(1.0996562341282203, -0.02749848619362501, 'Okay')])

# %%
plt.bar(Labels,values,color='blue',linewidth=5,linestyle='dashed')
plt.xlabel('Condition of House')
plt.ylabel('Count of the House')
plt.title('My first Graph')
# Out:
# Text(0.5, 1.0, 'My first Graph')

# %%
plt.scatter(x=DATA['Flat Area (in Sqft)'],y=DATA['Sale Price'],color='red')
plt.xlabel('Area')
plt.ylabel('Selling Price')
plt.title('Selling Price vs Area')
# Out:
# Text(0.5, 1.0, 'Selling Price vs Area')

# %%
plt.hist(DATA['Age of House (in Years)'],bins=12,)
plt.xlabel('Age of the house')
plt.ylabel('No. of records')
plt.title('Age wise distribution')
# Out:
# Text(0.5, 1.0, 'Age wise distribution')

# %%
plt.boxplot(DATA['Age of House (in Years)'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x15b33c652a0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x15b33c65840>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x15b33c64fd0>],
#  'medians': [<matplotlib.lines.Line2D at 0x15b33c65de0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x15b33c660b0>],
#  'means': []}

# %%
#creating new column with with its row values zero
DATA['condition_sale']=0 

# Ex:i=Good, then mean of all sale price where Condition of the House is Good will be assigned to all the rows of
# condition_sale where Condition of the House is Good
# Syntax: datase['Column_name'][Condition] 
for i in DATA['Condition of the House'].unique():
    DATA['condition_sale'][DATA['Condition of the House']==str(i)]=DATA['Sale Price'][DATA['Condition of the House']==str(i)].mean()


plt.figure(dpi=100)
plt.bar(DATA['Condition of the House'].unique(),DATA['condition_sale'].unique())
plt.xlabel('Condition of the House')
plt.ylabel('Mean Price')
# Out:
# C:\Users\Arjan\AppData\Local\Temp\ipykernel_26440\469028792.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DATA['condition_sale'][DATA['Condition of the House']==str(i)]=DATA['Sale Price'][DATA['Condition of the House']==str(i)].mean()
# Text(0, 0.5, 'Mean Price')

# %%
#mean of Sale Price w.r.t Condition of the House and Zipcode
#Syntax: dataset['Column_name'][(condition_1) & (condition_2)]

DATA['zipcode_condition_sale1']=0
c='Condition of the House'
z='Zipcode'
for i in DATA[c].unique():
    for j in DATA[z].unique():
        DATA['zipcode_condition_sale1'][(DATA[c]==str(i)) & (DATA[z]==j)] = DATA['Sale Price'][(DATA[c]==str(i)) & (DATA[z]==j)].mean()
len(DATA['zipcode_condition_sale1'].unique())
# Out:
# C:\Users\Arjan\AppData\Local\Temp\ipykernel_23564\570040153.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DATA['zipcode_condition_sale1'][(DATA[c]==str(i)) & (DATA[z]==j)] = DATA['Sale Price'][(DATA[c]==str(i)) & (DATA[z]==j)].mean()
# 281

# %%
#Syntax: dataframe.groupby(['list of columns to group by'])['column to be grouped'].how_to_group()

zip_condition_sale2=DATA.groupby(['Condition of the House','Zipcode'])['Sale Price'].mean()
zip_condition_sale2
# Out:
# Condition of the House  Zipcode
# Bad                     98004.0    1.500000e+06
#                         98006.0    3.725000e+05
#                         98011.0    2.700000e+05
#                         98023.0    1.500000e+05
#                         98024.0    1.420000e+05
#                                        ...
# Okay                    98155.0    3.601833e+05
#                         98166.0    2.165625e+05
#                         98168.0    1.809389e+05
#                         98178.0    1.750000e+05
#                         98198.0    2.705325e+05
# Name: Sale Price, Length: 283, dtype: float64

# %%
zipcode_condition_sale3=pandas.pivot_table(DATA,index=['Zipcode','Condition of the House'],values=['Sale Price'],aggfunc=np.mean)
zipcode_condition_sale3
# Out:
#                                    Sale Price
# Zipcode Condition of the House
# 98001.0 Excellent               242543.333333
#         Fair                    292720.693878
#         Good                    252744.618557
#         Okay                    356070.000000
# 98002.0 Excellent               221641.086957
# ...                                       ...
# 98198.0 Good                    315430.528846
#         Okay                    270532.500000
# 98199.0 Excellent               933898.285714
#         Fair                    760497.393939
#         Good                    796381.090909
#
# [283 rows x 1 columns]

# %%
zipcode_condition_sale4=pandas.pivot_table(DATA,index=['Zipcode'],columns=['Condition of the House'],values=['Sale Price'],aggfunc=np.mean)
zipcode_condition_sale4
# Out:
#                        Sale Price                                            \
# Condition of the House        Bad     Excellent          Fair          Good
# Zipcode
# 98001.0                       NaN  2.425433e+05  2.927207e+05  2.527446e+05
# 98002.0                       NaN  2.216411e+05  2.588868e+05  2.192858e+05
# 98003.0                       NaN  3.706800e+05  2.992801e+05  2.809591e+05
# 98004.0                 1500000.0  1.236365e+06  1.527265e+06  1.145915e+06
# 98005.0                       NaN  8.319500e+05  8.668012e+05  7.669397e+05
# ...                           ...           ...           ...           ...
# 98177.0                       NaN  8.966313e+05  6.496812e+05  6.665755e+05
# 98178.0                       NaN  2.975217e+05  3.094105e+05  3.308419e+05
# 98188.0                       NaN  2.853636e+05  2.900059e+05  2.867413e+05
# 98198.0                       NaN  3.215235e+05  2.941619e+05  3.154305e+05
# ...

# %%
# Replacing the values of Bad, Good, Excellent with 0, 1, 3 with Brute Force Method
DATA['Condition of the House'][DATA['Condition of the House']=='Fair']='1'
DATA['Condition of the House'][DATA['Condition of the House']=='Okay']='0'
DATA['Condition of the House'][DATA['Condition of the House']=='Bad']='0'
DATA['Condition of the House'][DATA['Condition of the House']=='Good']='1'
DATA['Condition of the House'][DATA['Condition of the House']=='Excellent']='3'
DATA['Condition of the House'].unique()
# Out:
# C:\Users\Arjan\AppData\Local\Temp\ipykernel_16820\2988961159.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DATA['Condition of the House'][DATA['Condition of the House']=='Fair']='1'
# C:\Users\Arjan\AppData\Local\Temp\ipykernel_16820\2988961159.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DATA['Condition of the House'][DATA['Condition of the House']=='Okay']='0'
# C:\Users\Arjan\AppData\Local\Temp\ipykernel_16820\2988961159.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
DATA['Condition of the House']=DATA['Condition of the House'].map({'Good':'1',
                                                                    'Excellent':'3',   
                                                                    'Bad':'0', 
                                                                    'Fair':'1', 
                                                                    'Okay':'0'})
DATA['Condition of the House'].unique()
# Out:
# array([nan], dtype=object)

# %%
# Assigning the values of a column to another column
year=[]
for i in range(len(DATA['Date House was Sold'])):
    k=DATA['Date House was Sold'][i].split()[-1]
    year.append(k)
DATA['Year Sold']=year
DATA['Year Sold'].head()
# Out:
# 0    14-Oct-17
# 1    14-Dec-17
# 2    15-Feb-16
# 3    14-Dec-17
# 4    15-Feb-16
# Name: Year Sold, dtype: object

# %%
# Assigning the values of a column to another column using pandas.map()
def year(value):
    return value.split()[-1]

DATA['year_sold']=DATA['Date House was Sold'].map(year)
DATA['year_sold'].head()
# Out:
# 0    14-Oct-17
# 1    14-Dec-17
# 2    15-Feb-16
# 3    14-Dec-17
# 4    15-Feb-16
# Name: year_sold, dtype: object

# %%
# Any two of the three conditions must be fulfilled for a home to be a luxury_home
DATA['luxury_home']=0
for i in range(len(DATA)):
    count=0
    if DATA['Waterfront View'][i]=='Yes':
        count+=1
    if DATA['Condition of the House'][i] in ['Good','Excellent']:
        count+=1
    if DATA['Overall Grade'][i]>=8:
        count=+1
    if count>=2:
        DATA['luxury_home'][i]='Yes'
    else:
        DATA['luxury_home'][i]='No'
DATA['luxury_home'].unique()
# Out:
# C:\Users\Arjan\AppData\Local\Temp\ipykernel_25976\1518733546.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DATA['luxury_home'][i]='No'
# array(['No', 'Yes'], dtype=object)

# %%
# Any two of the three conditions must be fulfilled for a home to be a luxury_home using apply()

def luxury_home(row):
    count=0
    if row[0]=='Yes':
        count=count+1
    if row[1] in ['Good','Excellent']:
        count=count+1
    if row[2]>=8:
        count=count+1
    if count>=2:
        return 'Yes'
    else:
        return 'No'                
DATA['luxury_home'] = DATA[['Waterfront View','Condition of the House','Overall Grade']].apply(luxury_home,axis=1)   
DATA['luxury_home'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)
